# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

getdata = pd.read_csv('C:/Users/AhmerZunair/Desktop/dataset_60features/final61features.csv')
data = pd.DataFrame(getdata)
data.columns =['MSISDN','ACCOUNT','Phone','XDRID','IMSI','IMEI','MachineIPAddType','SGWGGSNIPAdd','TAC','ECI','APN','AppTypeCode','RequestTime','ProcedureEndTime','ProtocolType','AppType','AppSubType','AppContent','AppStatus','USER_IPv4','UserPort','L4Protocal','AppServerIP_IPv4','AppServerPort','ULTraffic','DLTraffic','ULIPPacket','DLIPPacket','ULTCPOoOPacket','DLTCPOoOPacket','DLTCPRetransPacket','TCPSYNAtteDelay','TCPSYNComfirmDelay','ULIPFRAGPACKETS','DLIPFRAGPACKETS','TCPSYNSuccFirstReqDelay','FirstReqToFirstResDelay','WindowSize','MSSSize','TCPSYNAtte','TCPConnStatus','SessionIsEnd','EventType','HTTPWAPStatus','FirstHTTPResPacketDelay','LastHTTPPacketDelay','LastACKPacketDelay','HOST','URI','XOnlineHost','UserAgent','HTTP_content_type','ULTCPRetransPacket','refer_URI','Cookie','ContentLength','DestBeha','OperBehaIden','OperFinishIden','OperDelay','Browser','PortalAppCollection','a','b']
print(data)
msisdn = data['MSISDN']
ports = data['TAC']
account = data['ACCOUNT']
imei = data['IMEI']
#print(ports)
#df = pd.DataFrame(msisdn, index=ports, columns=list('ABCD'))

#df = df.cumsum()
a = msisdn.head(100)
b = ports.head(100)
c = account.head(100)
d = imei.head(100)
plt.scatter(a,b)
#plt.scatter(a,c)
#plt.subplot(c,d) # creates 2nd subplot with yellow background

plt.show()
# Out:
#                     MSISDN  ACCOUNT        Phone             XDRID  IMSI  \
# 0       100266749193597577     8532  13786143393  1d0b015e2d2f0200   NaN
# 1       100266749193597577     8532  13786143393  1d0b015e33b09d00   NaN
# 2       100266749193597577     8532  13786143393  1d0b015e33b12400   NaN
# 3       100266749193597577     8532  13786143393  1d0b015e33b1de00   NaN
# 4       100266749193597577     8532  13786143393  1d0b015e33b27900   NaN
# 5       100266749193597577     8532  13786143393  1d0b015e33b30800   NaN
# 6       100266749193597577     8532  13786143393  1d0b015e33b3c000   NaN
# 7       100266749193597577     8532  13786143393  1d0b015e33b45c00   NaN
# 8       100266749193597577     8532  13786143393  1d0b015e33b4f200   NaN
# 9       100266749193597577     8532  13786143393  1d0b015e33b5ab00   NaN
# 10      100266749193597577     8532  13786143393  1d0b015e33b66b00   NaN
# 11      100266749193597577     8532  13786143393  1d0b015e36674700   NaN
# ...
